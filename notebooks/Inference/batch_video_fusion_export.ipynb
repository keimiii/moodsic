# %% [markdown]
# # Batch PERCEIVE Export
#
# Run the PERCEIVE pipeline over every video in `data/videos/` and export
# per-frame scene, face, and fused results to JSON for both stabilizer
# settings.

# %%
# Setup: repository path and imports
import sys
import json
import math
import torch.serialization
from fastai.learner import Learner

torch.serialization.add_safe_globals([Learner])
# then instantiate SceneCLIPAdapter as before

from pathlib import Path

repo_root = Path.cwd()
if repo_root.name == "notebooks":
    repo_root = repo_root.parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from utils.runtime_driver import perceive_video

print("Repo root:", repo_root)
# Out:
# Repo root: /Users/desmondchoy/Projects/emo-rec

# %%
# Adapters (best effort)
scene_adapter = None
face_processor = None
face_adapter = None

try:
    from models.scene.clip_vit_scene_adapter import SceneCLIPAdapter

    scene_adapter = SceneCLIPAdapter(
        model_name="openai/clip-vit-base-patch32",
        dropout_rate=0.3,
        device="auto",
        tta=3,
        weights_path="scene/checkpoints/clip_vit-b32_improved_head.pth",
        auto_load_best=False,  # avoids falling back to the .pkl if this load fails
    )

    print("SceneCLIPAdapter: OK")
except Exception as exc:
    print(f"SceneCLIPAdapter unavailable: {exc}")

try:
    from utils.emonet_single_face_processor import EmoNetSingleFaceProcessor

    face_processor = EmoNetSingleFaceProcessor(
        min_detection_confidence=0.5, padding_ratio=0.2
    )
    if face_processor.available:
        print("EmoNetSingleFaceProcessor: OK")
    else:
        print("EmoNetSingleFaceProcessor: MediaPipe detector unavailable")
except Exception as exc:
    print(f"Face processor unavailable: {exc}")

try:
    from models.face.emonet_adapter import EmoNetAdapter

    face_adapter = EmoNetAdapter(
        ckpt_dir="models/emonet/pretrained",
        n_classes=8,
        device="auto",
        tta=3,
    )
    print("EmoNetAdapter: OK")
except Exception as exc:
    print(f"EmoNetAdapter unavailable: {exc}")
# Out:
# SceneCLIPAdapter: OK
# EmoNetSingleFaceProcessor: OK
# EmoNetAdapter: OK
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759561511.974926  502581 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 90.5), renderer: Apple M4 Pro
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1759561511.983874  502863 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %% [markdown]
# * `SCENE_TTA` – Scene adapter MC-dropout sample count per frame; higher (e.g., 5) means more stochastic passes, stronger smoothing, and richer variance estimates at higher compute cost, while lower (e.g., 1) is fast but collapses scene variance and leaves predictions noisier.
# * `FACE_TTA` – Number of augmented face crops per frame (original + flip/jitter); increasing (e.g., 5) averages more variants for steadier face scores and non-zero variance but costs time, decreasing (e.g., 1) reverts to a single deterministic pass that is quicker yet more jittery with little uncertainty signal.
# * `TARGET_SAMPLE_FPS` – Desired frame sampling rate; raising captures finer temporal detail and more compute, lowering skips nuance to save time.
# * `MAX_FRAMES` – Hard cap on frames processed; enforcing a limit bounds runtime/memory but may miss long-range context, None processes entire clips.
# * `USE_VARIANCE_WEIGHTING` – Enables inverse-variance fusion so consistent opinions dominate; disabling falls back to fixed weights, letting noisy paths influence the result equally.
# * `SCENE_WEIGHT` – Fixed fallback weight for scene path when variance fusion can’t run; higher favors global context, lower reduces its voice.
# * `FACE_WEIGHT` – Fixed fallback weight for face path; increasing leans into facial cues when variance data is missing, decreasing dampens them. Keep scene_weight + face_weight sensible.
# * `FACE_SCORE_THRESHOLD` – Minimum face confidence; lifting it drops weak detections (less jitter but more gaps), lowering keeps borderline faces (more coverage, more noise).
# * `FACE_MAX_SIGMA` – Ceiling on face uncertainty (sigma) before gating; tighter caps ignore very uncertain face outputs, looser/None leaves them in the mix.
# * `BRIGHTNESS_THRESHOLD` – Luma floor for using face results; higher filters dim frames (steadier but risky in low light), lower keeps more frames (better coverage, noisier in dark scenes).

# %% [markdown]
# Stabilizer Settings:

# %% [markdown]
# * `UNCERTAINTY_THRESHOLD` – Variance level that triggers the stabilizer’s hold; lower values freeze outputs more often, higher values let raw updates through unless they’re very uncertain.
# * `STABILIZER_WINDOW` – Rolling window for jitter/variance metrics; longer windows give smoother but laggier stability stats, shorter windows react faster with more fluctuation.
# * `STABILIZER_ALPHA` – EMA blend factor; higher alpha tracks new values quickly (less smoothing), lower alpha leans on history for steadier but slower responses.

# %%
# Configuration
VIDEO_DIR = repo_root / "data" / "VEATIC" / "videos"
OUTPUT_ROOT = repo_root / "results" / "inference"
VIDEO_EXTENSIONS = (".mp4", ".mov", ".mkv", ".avi")

SCENE_TTA = 3
FACE_TTA = 3
TARGET_SAMPLE_FPS = 1.0
MAX_FRAMES = None  # e.g., 600 to cap processing time
USE_VARIANCE_WEIGHTING = True
SCENE_WEIGHT = 0.6
FACE_WEIGHT = 0.4
FACE_SCORE_THRESHOLD = None
FACE_MAX_SIGMA = None
BRIGHTNESS_THRESHOLD = None

# Stabilizer parameters (used when enable_stabilizer=True)
UNCERTAINTY_THRESHOLD = 0.4
STABILIZER_WINDOW = 60
STABILIZER_ALPHA = 0.7

OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)
print("Video directory:", VIDEO_DIR)
print("Output root:", OUTPUT_ROOT)
# Out:
# Video directory: /Users/desmondchoy/Projects/emo-rec/data/VEATIC/videos
# Output root: /Users/desmondchoy/Projects/emo-rec/results/inference

# %%
# Helpers
from typing import List, Dict, Any


def list_videos() -> List[Path]:
    if not VIDEO_DIR.exists():
        return []
    videos: List[Path] = []
    for ext in VIDEO_EXTENSIONS:
        videos.extend(VIDEO_DIR.glob(f"*{ext}"))
    return sorted(videos)


def _clean_sequence(values: List[float]) -> List[Any]:
    cleaned: List[Any] = []
    for value in values:
        if isinstance(value, float):
            if math.isfinite(value):
                cleaned.append(float(value))
            else:
                cleaned.append(None)
        else:
            cleaned.append(value)
    return cleaned


def _coverage(series) -> float:
    total = len(series.valence)
    if total == 0:
        return 0.0
    valid = sum(1 for v in series.valence if isinstance(v, float) and math.isfinite(v))
    return valid / total


def series_to_dict(series, include_coverage: bool = False) -> Dict[str, Any]:
    data: Dict[str, Any] = {
        "valence": _clean_sequence(series.valence),
        "arousal": _clean_sequence(series.arousal),
        "var_valence": _clean_sequence(series.var_valence),
        "var_arousal": _clean_sequence(series.var_arousal),
        "mean_valence": series.mean_valence,
        "mean_arousal": series.mean_arousal,
        "median_valence": series.median_valence,
        "median_arousal": series.median_arousal,
        "mode_valence": series.mode_valence,
        "mode_arousal": series.mode_arousal,
    }
    if include_coverage:
        data["coverage"] = _coverage(series)
    return data


def build_payload(result, *, enable_stabilizer: bool) -> Dict[str, Any]:
    if result.fps and result.fps > 0:
        timestamps = [idx / result.fps for idx in result.frame_indices]
    else:
        timestamps = [None] * len(result.frame_indices)

    return {
        "video": {
            "path": str(result.video_path),
            "width": result.width,
            "height": result.height,
            "fps": result.fps,
            "frame_count": result.frame_count,
        },
        "processing": {
            "processed_frames": result.processed_frames,
            "sample_stride": result.sample_stride,
            "effective_fps": result.effective_fps,
            "enable_stabilizer": enable_stabilizer,
            "scene_tta": SCENE_TTA,
            "face_tta": FACE_TTA,
            "target_sample_fps": TARGET_SAMPLE_FPS,
            "max_frames": MAX_FRAMES,
            "use_variance_weighting": USE_VARIANCE_WEIGHTING,
            "scene_weight": SCENE_WEIGHT,
            "face_weight": FACE_WEIGHT,
            "uncertainty_threshold": UNCERTAINTY_THRESHOLD
            if enable_stabilizer
            else None,
            "stabilizer_window": STABILIZER_WINDOW if enable_stabilizer else None,
            "stabilizer_alpha": STABILIZER_ALPHA if enable_stabilizer else None,
        },
        "samples": {
            "frame_indices": list(result.frame_indices),
            "timestamps_sec": timestamps,
            "scene": series_to_dict(result.scene_result),
            "face": series_to_dict(result.face_result, include_coverage=True),
            "fusion": series_to_dict(result.fusion_result),
        },
    }


def export_batch(
    enable_stabilizer: bool, *, capture_overlays: bool = False
) -> List[Path]:
    videos = list_videos()
    label = "stabilized" if enable_stabilizer else "unstabilized"
    out_dir = OUTPUT_ROOT / label
    out_dir.mkdir(parents=True, exist_ok=True)

    if not videos:
        print(f"No videos found in {VIDEO_DIR}")
        return []

    saved: List[Path] = []
    for video_path in videos:
        print(f"[{label}] Processing {video_path.name} ...", end=" ")
        result = perceive_video(
            video_path,
            scene_predictor=scene_adapter,
            face_processor=face_processor,
            face_expert=face_adapter,
            scene_tta=SCENE_TTA,
            face_tta=FACE_TTA,
            target_sample_fps=TARGET_SAMPLE_FPS,
            max_frames=MAX_FRAMES,
            use_variance_weighting=USE_VARIANCE_WEIGHTING,
            scene_weight=SCENE_WEIGHT,
            face_weight=FACE_WEIGHT,
            face_score_threshold=FACE_SCORE_THRESHOLD,
            face_max_sigma=FACE_MAX_SIGMA,
            brightness_threshold=BRIGHTNESS_THRESHOLD,
            enable_stabilizer=enable_stabilizer,
            stabilizer_alpha=STABILIZER_ALPHA,
            uncertainty_threshold=UNCERTAINTY_THRESHOLD,
            stabilizer_window=STABILIZER_WINDOW,
            capture_overlays=capture_overlays,
            return_fusion=False,
        )

        payload = build_payload(result, enable_stabilizer=enable_stabilizer)
        dest = out_dir / f"{video_path.stem}.json"
        with dest.open("w", encoding="utf-8") as fh:
            json.dump(payload, fh, indent=2, ensure_ascii=False, allow_nan=False)
        saved.append(dest)
        print("done")

    return saved

# %%
# Run batch export (stabilizer OFF)
unstabilized_outputs = export_batch(enable_stabilizer=False)
print(f"Unstabilized exports: {len(unstabilized_outputs)} files")
# Out:
# [unstabilized] Processing 0.mp4 ...
# I0000 00:00:1759561512.247914  502581 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 90.5), renderer: Apple M4 Pro
# W0000 00:00:1759561512.248699  502908 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# done
# [unstabilized] Processing 1.mp4 ... done
# [unstabilized] Processing 10.mp4 ... done
# [unstabilized] Processing 100.mp4 ... done
# [unstabilized] Processing 101.mp4 ... done
# [unstabilized] Processing 102.mp4 ... done
# [unstabilized] Processing 103.mp4 ... done
# [unstabilized] Processing 104.mp4 ... done
# [unstabilized] Processing 105.mp4 ... done
# [unstabilized] Processing 106.mp4 ... done
# [unstabilized] Processing 107.mp4 ... done
# [unstabilized] Processing 108.mp4 ... done
# [unstabilized] Processing 109.mp4 ... done
# [unstabilized] Processing 11.mp4 ... done
# [unstabilized] Processing 110.mp4 ... done
# [unstabilized] Processing 111.mp4 ... done
# [unstabilized] Processing 112.mp4 ... done
# [unstabilized] Processing 113.mp4 ... done
# [unstabilized] Processing 114.mp4 ... done
# [unstabilized] Processing 115.mp4 ... done
# [unstabilized] Processing 116.mp4 ... done
# [unstabilized] Processing 117.mp4 ... done
# [unstabilized] Processing 118.mp4 ... done
# [unstabilized] Processing 119.mp4 ... done
# [unstabilized] Processing 12.mp4 ... done
# [unstabilized] Processing 120.mp4 ... done
# [unstabilized] Processing 121.mp4 ... done
# [unstabilized] Processing 122.mp4 ... done
# [unstabilized] Processing 123.mp4 ... done
# [unstabilized] Processing 13.mp4 ... done
# [unstabilized] Processing 14.mp4 ... done
# [unstabilized] Processing 15.mp4 ... done
# [unstabilized] Processing 16.mp4 ... done
# [unstabilized] Processing 17.mp4 ... done
# [unstabilized] Processing 18.mp4 ... done
# [unstabilized] Processing 19.mp4 ... done
# [unstabilized] Processing 2.mp4 ... done
# [unstabilized] Processing 20.mp4 ... done
# [unstabilized] Processing 21.mp4 ... done
# [unstabilized] Processing 22.mp4 ... done
# [unstabilized] Processing 23.mp4 ... done
# [unstabilized] Processing 24.mp4 ... done
# [unstabilized] Processing 25.mp4 ... done
# [unstabilized] Processing 26.mp4 ... done
# [unstabilized] Processing 27.mp4 ... done
# [unstabilized] Processing 28.mp4 ... done
# [unstabilized] Processing 29.mp4 ... done
# [unstabilized] Processing 3.mp4 ... done
# [unstabilized] Processing 30.mp4 ... done
# [unstabilized] Processing 31.mp4 ... done
# [unstabilized] Processing 32.mp4 ... done
# [unstabilized] Processing 33.mp4 ... done
# [unstabilized] Processing 34.mp4 ... done
# [unstabilized] Processing 35.mp4 ... done
# [unstabilized] Processing 36.mp4 ... done
# [unstabilized] Processing 37.mp4 ... done
# [unstabilized] Processing 38.mp4 ... done
# [unstabilized] Processing 39.mp4 ... done
# [unstabilized] Processing 4.mp4 ... done
# [unstabilized] Processing 40.mp4 ... done
# [unstabilized] Processing 41.mp4 ... done
# [unstabilized] Processing 42.mp4 ... done
# [unstabilized] Processing 43.mp4 ... done
# [unstabilized] Processing 44.mp4 ... done
# [unstabilized] Processing 45.mp4 ... done
# [unstabilized] Processing 46.mp4 ... done
# [unstabilized] Processing 47.mp4 ... done
# [unstabilized] Processing 48.mp4 ... done
# [unstabilized] Processing 49.mp4 ... done
# [unstabilized] Processing 5.mp4 ... done
# [unstabilized] Processing 50.mp4 ... done
# [unstabilized] Processing 51.mp4 ... done
# [unstabilized] Processing 52.mp4 ... done
# [unstabilized] Processing 53.mp4 ... done
# [unstabilized] Processing 54.mp4 ... done
# [unstabilized] Processing 55.mp4 ... done
# [unstabilized] Processing 56.mp4 ... done
# [unstabilized] Processing 57.mp4 ... done
# [unstabilized] Processing 58.mp4 ... done
# [unstabilized] Processing 59.mp4 ... done
# [unstabilized] Processing 6.mp4 ... done
# [unstabilized] Processing 60.mp4 ... done
# [unstabilized] Processing 61.mp4 ... done
# [unstabilized] Processing 62.mp4 ... done
# [unstabilized] Processing 63.mp4 ... done
# [unstabilized] Processing 64.mp4 ... done
# [unstabilized] Processing 65.mp4 ... done
# [unstabilized] Processing 66.mp4 ... done
# [unstabilized] Processing 67.mp4 ... done
# [unstabilized] Processing 68.mp4 ... done
# [unstabilized] Processing 69.mp4 ... done
# [unstabilized] Processing 7.mp4 ... done
# [unstabilized] Processing 70.mp4 ... done
# [unstabilized] Processing 71.mp4 ... done
# [unstabilized] Processing 72.mp4 ... done
# [unstabilized] Processing 73.mp4 ... done
# [unstabilized] Processing 74.mp4 ... done
# [unstabilized] Processing 75.mp4 ... done
# [unstabilized] Processing 76.mp4 ... done
# [unstabilized] Processing 77.mp4 ... done
# [unstabilized] Processing 78.mp4 ... done
# [unstabilized] Processing 79.mp4 ... done
# [unstabilized] Processing 8.mp4 ... done
# [unstabilized] Processing 80.mp4 ... done
# [unstabilized] Processing 81.mp4 ... done
# [unstabilized] Processing 82.mp4 ... done
# [unstabilized] Processing 83.mp4 ... done
# [unstabilized] Processing 84.mp4 ... done
# [unstabilized] Processing 85.mp4 ... done
# [unstabilized] Processing 86.mp4 ... done
# [unstabilized] Processing 87.mp4 ... done
# [unstabilized] Processing 88.mp4 ... done
# [unstabilized] Processing 89.mp4 ... done
# [unstabilized] Processing 9.mp4 ... done
# [unstabilized] Processing 90.mp4 ... done
# [unstabilized] Processing 91.mp4 ... done
# [unstabilized] Processing 92.mp4 ... done
# [unstabilized] Processing 93.mp4 ... done
# [unstabilized] Processing 94.mp4 ... done
# [unstabilized] Processing 95.mp4 ... done
# [unstabilized] Processing 96.mp4 ... done
# [unstabilized] Processing 97.mp4 ... done
# [unstabilized] Processing 98.mp4 ... done
# [unstabilized] Processing 99.mp4 ... done
# Unstabilized exports: 124 files

# %%
# Run batch export (stabilizer ON)
stabilized_outputs = export_batch(enable_stabilizer=True)
print(f"Stabilized exports: {len(stabilized_outputs)} files")
# Out:
# [stabilized] Processing 0.mp4 ... done
# [stabilized] Processing 1.mp4 ... done
# [stabilized] Processing 10.mp4 ... done
# [stabilized] Processing 100.mp4 ... done
# [stabilized] Processing 101.mp4 ... done
# [stabilized] Processing 102.mp4 ... done
# [stabilized] Processing 103.mp4 ... done
# [stabilized] Processing 104.mp4 ... done
# [stabilized] Processing 105.mp4 ... done
# [stabilized] Processing 106.mp4 ... done
# [stabilized] Processing 107.mp4 ... done
# [stabilized] Processing 108.mp4 ... done
# [stabilized] Processing 109.mp4 ... done
# [stabilized] Processing 11.mp4 ... done
# [stabilized] Processing 110.mp4 ... done
# [stabilized] Processing 111.mp4 ... done
# [stabilized] Processing 112.mp4 ... done
# [stabilized] Processing 113.mp4 ... done
# [stabilized] Processing 114.mp4 ... done
# [stabilized] Processing 115.mp4 ... done
# [stabilized] Processing 116.mp4 ... done
# [stabilized] Processing 117.mp4 ... done
# [stabilized] Processing 118.mp4 ... done
# [stabilized] Processing 119.mp4 ... done
# [stabilized] Processing 12.mp4 ... done
# [stabilized] Processing 120.mp4 ... done
# [stabilized] Processing 121.mp4 ... done
# [stabilized] Processing 122.mp4 ... done
# [stabilized] Processing 123.mp4 ... done
# [stabilized] Processing 13.mp4 ... done
# [stabilized] Processing 14.mp4 ... done
# [stabilized] Processing 15.mp4 ... done
# [stabilized] Processing 16.mp4 ... done
# [stabilized] Processing 17.mp4 ... done
# [stabilized] Processing 18.mp4 ... done
# [stabilized] Processing 19.mp4 ... done
# [stabilized] Processing 2.mp4 ... done
# [stabilized] Processing 20.mp4 ... done
# [stabilized] Processing 21.mp4 ... done
# [stabilized] Processing 22.mp4 ... done
# [stabilized] Processing 23.mp4 ... done
# [stabilized] Processing 24.mp4 ... done
# [stabilized] Processing 25.mp4 ... done
# [stabilized] Processing 26.mp4 ... done
# [stabilized] Processing 27.mp4 ... done
# [stabilized] Processing 28.mp4 ... done
# [stabilized] Processing 29.mp4 ... done
# [stabilized] Processing 3.mp4 ... done
# [stabilized] Processing 30.mp4 ... done
# [stabilized] Processing 31.mp4 ... done
# [stabilized] Processing 32.mp4 ... done
# [stabilized] Processing 33.mp4 ... done
# [stabilized] Processing 34.mp4 ... done
# [stabilized] Processing 35.mp4 ... done
# [stabilized] Processing 36.mp4 ... done
# [stabilized] Processing 37.mp4 ... done
# [stabilized] Processing 38.mp4 ... done
# [stabilized] Processing 39.mp4 ... done
# [stabilized] Processing 4.mp4 ... done
# [stabilized] Processing 40.mp4 ... done
# [stabilized] Processing 41.mp4 ... done
# [stabilized] Processing 42.mp4 ... done
# [stabilized] Processing 43.mp4 ... done
# [stabilized] Processing 44.mp4 ... done
# [stabilized] Processing 45.mp4 ... done
# [stabilized] Processing 46.mp4 ... done
# [stabilized] Processing 47.mp4 ... done
# [stabilized] Processing 48.mp4 ... done
# [stabilized] Processing 49.mp4 ... done
# [stabilized] Processing 5.mp4 ... done
# [stabilized] Processing 50.mp4 ... done
# [stabilized] Processing 51.mp4 ... done
# [stabilized] Processing 52.mp4 ... done
# [stabilized] Processing 53.mp4 ... done
# [stabilized] Processing 54.mp4 ... done
# [stabilized] Processing 55.mp4 ... done
# [stabilized] Processing 56.mp4 ... done
# [stabilized] Processing 57.mp4 ... done
# [stabilized] Processing 58.mp4 ... done
# [stabilized] Processing 59.mp4 ... done
# [stabilized] Processing 6.mp4 ... done
# [stabilized] Processing 60.mp4 ... done
# [stabilized] Processing 61.mp4 ... done
# [stabilized] Processing 62.mp4 ... done
# [stabilized] Processing 63.mp4 ... done
# [stabilized] Processing 64.mp4 ... done
# [stabilized] Processing 65.mp4 ... done
# [stabilized] Processing 66.mp4 ... done
# [stabilized] Processing 67.mp4 ... done
# [stabilized] Processing 68.mp4 ... done
# [stabilized] Processing 69.mp4 ... done
# [stabilized] Processing 7.mp4 ... done
# [stabilized] Processing 70.mp4 ... done
# [stabilized] Processing 71.mp4 ... done
# [stabilized] Processing 72.mp4 ... done
# [stabilized] Processing 73.mp4 ... done
# [stabilized] Processing 74.mp4 ... done
# [stabilized] Processing 75.mp4 ... done
# [stabilized] Processing 76.mp4 ... done
# [stabilized] Processing 77.mp4 ... done
# [stabilized] Processing 78.mp4 ... done
# [stabilized] Processing 79.mp4 ... done
# [stabilized] Processing 8.mp4 ... done
# [stabilized] Processing 80.mp4 ... done
# [stabilized] Processing 81.mp4 ... done
# [stabilized] Processing 82.mp4 ... done
# [stabilized] Processing 83.mp4 ... done
# [stabilized] Processing 84.mp4 ... done
# [stabilized] Processing 85.mp4 ... done
# [stabilized] Processing 86.mp4 ... done
# [stabilized] Processing 87.mp4 ... done
# [stabilized] Processing 88.mp4 ... done
# [stabilized] Processing 89.mp4 ... done
# [stabilized] Processing 9.mp4 ... done
# [stabilized] Processing 90.mp4 ... done
# [stabilized] Processing 91.mp4 ... done
# [stabilized] Processing 92.mp4 ... done
# [stabilized] Processing 93.mp4 ... done
# [stabilized] Processing 94.mp4 ... done
# [stabilized] Processing 95.mp4 ... done
# [stabilized] Processing 96.mp4 ... done
# [stabilized] Processing 97.mp4 ... done
# [stabilized] Processing 98.mp4 ... done
# [stabilized] Processing 99.mp4 ... done
# Stabilized exports: 124 files
